# %% [markdown]
# <a href="https://colab.research.google.com/github/rapu34/Player-Contact-Detection/blob/main/Yolov8%2BDeepsort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Pip install method (recommended)
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.35 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.4/78.2 GB disk)

# %%
from ultralytics import YOLO

# %%
# model = YOLO("/content/drive/MyDrive/nfl-player-contact-detection/player_best.pt")

# %%
# results = model("/content/drive/MyDrive/nfl-player-contact-detection/train/58168_003392_Sideline.mp4")

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/nfl-player-contact-detection/player_best.pt" conf=0.25 source='/content/drive/MyDrive/nfl-player-contact-detection/train/58168_003392_Sideline.mp4' save=True
# Out:
# Ultralytics YOLOv8.0.35 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (1/711) /content/drive/MyDrive/nfl-player-contact-detection/train/58168_003392_Sideline.mp4: 480x800 5 DBs, 3 LBs, 1 QB, 4 SKILLs, 17.5ms
# video 1/1 (2/711) /content/drive/MyDrive/nfl-player-contact-detection/train/58168_003392_Sideline.mp4: 480x800 4 DBs, 3 LBs, 1 QB, 4 SKILLs, 16.5ms
# video 1/1 (3/711) /content/drive/MyDrive/nfl-player-contact-detection/train/58168_003392_Sideline.mp4: 480x800 1 CENTER, 4 DBs, 3 LBs, 1 QB, 4 SKILLs, 16.4ms
# video 1/1 (4/711) /content/drive/MyDrive/nfl-player-contact-detection/train/58168_003392_Sideline.mp4: 480x800 1 CENTER, 4 DBs, 3 LBs, 1 QB, 4 SKILLs, 16.4ms
# video 1/1 (5/711) /content/drive/MyDrive/nfl-player-contact-detection/train/58168_003392_Sideline.mp4: 480x800 1 CENTER, 4 DBs, 3 LBs, 1 QB, 4 SKILLs, 16.5ms
# ...

# %%
# !git clone https://github.com/MuhammadMoinFaisal/YOLOv8-DeepSORT-Object-Tracking.git
# Out:
# fatal: destination path 'YOLOv8-DeepSORT-Object-Tracking' already exists and is not an empty directory.

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking 5
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking

# %%
# !pip install -e '.[dev]'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect
# ERROR: file:///content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %%
# !gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t
# To: /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/deep_sort_pytorch.zip
# 100% 43.1M/43.1M [00:00<00:00, 287MB/s]

# %%
# !unzip 'deep_sort_pytorch.zip'
# Out:
# Archive:  deep_sort_pytorch.zip
#   inflating: deep_sort_pytorch/.gitignore
#    creating: deep_sort_pytorch/configs/
#   inflating: deep_sort_pytorch/configs/deep_sort.yaml
#    creating: deep_sort_pytorch/deep_sort/
#   inflating: deep_sort_pytorch/deep_sort/__init__.py
#    creating: deep_sort_pytorch/deep_sort/__pycache__/
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-310.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-37.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-38.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-310.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-37.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-38.pyc
#    creating: deep_sort_pytorch/deep_sort/deep/
#  extracting: deep_sort_pytorch/deep_sort/deep/__init__.py
#    creating: deep_sort_pytorch/deep_sort/deep/__pycache__/
# ...

# %%
# !python predict.py source="/content/runs/detect/predict/58168_003392_Sideline.mp4"
# Out:
# [2023-02-12 16:34:30,564][root.tracker][INFO] - Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# Ultralytics YOLOv8.0.3 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Fusing layers...
# YOLOv8n summary: 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# video 1/1 (1/711) /content/runs/detect/predict/58168_003392_Sideline.mp4: 384x640 16.2ms
# video 1/1 (2/711) /content/runs/detect/predict/58168_003392_Sideline.mp4: 384x640 8.2ms
# video 1/1 (3/711) /content/runs/detect/predict/58168_003392_Sideline.mp4: 384x640 1 person, 8.9ms
# video 1/1 (4/711) /content/runs/detect/predict/58168_003392_Sideline.mp4: 384x640 9.0ms
# video 1/1 (5/711) /content/runs/detect/predict/58168_003392_Sideline.mp4: 384x640 1 person, 8.8ms
# video 1/1 (6/711) /content/runs/detect/predict/58168_003392_Sideline.mp4: 384x640 12.2ms
# video 1/1 (7/711) /content/runs/detect/predict/58168_003392_Sideline.mp4: 384x640 8.9ms
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train/58168_003392_Sideline.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
# result_compressed.mp4 결과 출력
